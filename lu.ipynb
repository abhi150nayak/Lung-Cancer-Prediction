# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
data=pd.read_csv("lung_cancer_examples.csv")
data
# Out:
#       Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0     John         Wick   35       3      5       4       1
# 1     John  Constantine   27      20      2       5       1
# 2   Camela     Anderson   30       0      5       2       0
# 3     Alex       Telles   28       0      0       1       0
# 4    Diego     Maradona   68       4      5       6       1
# ..     ...          ...  ...     ...    ...     ...     ...
# 94   Sunny        Dagel   20      18      0       4       0
# 95  Salman          Boi   65      14      1       5       0
# 96   Ameer         Lary   55      12      8       9       0
# 97     Ram       Charan   45      20      5       5       1
# 98    Allu         Ally   49      15      9       9       1
#
# [99 rows x 7 columns]

# %%
#The info() method prints information about the DataFrame.
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     99 non-null     object
#  1   Surname  99 non-null     object
#  2   Age      99 non-null     int64
#  3   Smokes   99 non-null     int64
#  4   AreaQ    99 non-null     int64
#  5   Alkhol   99 non-null     int64
#  6   Result   99 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 5.5+ KB
# None

# %%
#Returns the first n rows.
data.head(10)
# Out:
#         Name      Surname  Age  Smokes  AreaQ  Alkhol  Result
# 0       John         Wick   35       3      5       4       1
# 1       John  Constantine   27      20      2       5       1
# 2     Camela     Anderson   30       0      5       2       0
# 3       Alex       Telles   28       0      0       1       0
# 4      Diego     Maradona   68       4      5       6       1
# 5  Cristiano      Ronaldo   34       0     10       0       1
# 6     Mihail          Tal   58      15     10       0       1
# 7      Kathy        Bates   22      12      5       2       1
# 8     Nicole       Kidman   45       2      6       0       1
# 9        Ray      Milland   52      18      4       5       1

# %%
#The tail() function is used to get the last n rows.
data.tail(10)
# Out:
#       Name Surname  Age  Smokes  AreaQ  Alkhol  Result
# 89   Jacly     boi   33      15      0       7       0
# 90   Jacky    Chan   45      20      9       3       1
# 91   Soman     Fer   66      19      5       4       1
# 92   Johny    Sins   45      22      8       8       1
# 93    Joel    Fery   33      25      7       7       1
# 94   Sunny   Dagel   20      18      0       4       0
# 95  Salman     Boi   65      14      1       5       0
# 96   Ameer    Lary   55      12      8       9       0
# 97     Ram  Charan   45      20      5       5       1
# 98    Allu    Ally   49      15      9       9       1

# %%
#Pandas dataframe.isna() function is used to detect missing values. It return a boolean same-sized object indicating if the values are NA. 
print(data.isna())
# Out:
#      Name  Surname    Age  Smokes  AreaQ  Alkhol  Result
# 0   False    False  False   False  False   False   False
# 1   False    False  False   False  False   False   False
# 2   False    False  False   False  False   False   False
# 3   False    False  False   False  False   False   False
# 4   False    False  False   False  False   False   False
# ..    ...      ...    ...     ...    ...     ...     ...
# 94  False    False  False   False  False   False   False
# 95  False    False  False   False  False   False   False
# 96  False    False  False   False  False   False   False
# 97  False    False  False   False  False   False   False
# 98  False    False  False   False  False   False   False
#
# [99 rows x 7 columns]

# %%
#checking null values
print(data.notnull())
# Out:
#     Name  Surname   Age  Smokes  AreaQ  Alkhol  Result
# 0   True     True  True    True   True    True    True
# 1   True     True  True    True   True    True    True
# 2   True     True  True    True   True    True    True
# 3   True     True  True    True   True    True    True
# 4   True     True  True    True   True    True    True
# ..   ...      ...   ...     ...    ...     ...     ...
# 94  True     True  True    True   True    True    True
# 95  True     True  True    True   True    True    True
# 96  True     True  True    True   True    True    True
# 97  True     True  True    True   True    True    True
# 98  True     True  True    True   True    True    True
#
# [99 rows x 7 columns]

# %%
#isna().sum() returns the number of missing values in each column.
data.isna().sum()
# Out:
# Name       0
# Surname    0
# Age        0
# Smokes     0
# AreaQ      0
# Alkhol     0
# Result     0
# dtype: int64

# %%
#The describe() method returns description of the data in the DataFrame.
data.describe()
# Out:
#              Age    Smokes      AreaQ     Alkhol     Result
# count  99.000000  99.00000  99.000000  99.000000  99.000000
# mean   39.323232  15.89899   4.828283   4.252525   0.717172
# std    16.884257   7.33804   3.080685   2.730566   0.452666
# min    18.000000   0.00000   0.000000   0.000000   0.000000
# 25%    24.000000  12.00000   2.000000   2.000000   0.000000
# 50%    35.000000  18.00000   5.000000   4.000000   1.000000
# 75%    52.500000  20.00000   8.000000   7.000000   1.000000
# max    77.000000  34.00000  10.000000   9.000000   1.000000

# %%
  #data cleaning

  data1 = data.drop(columns=['Name','Surname'], axis=1)
  data1.head(10)
# Out:
#    Age  Smokes  AreaQ  Alkhol  Result
# 0   35       3      5       4       1
# 1   27      20      2       5       1
# 2   30       0      5       2       0
# 3   28       0      0       1       0
# 4   68       4      5       6       1
# 5   34       0     10       0       1
# 6   58      15     10       0       1
# 7   22      12      5       2       1
# 8   45       2      6       0       1
# 9   52      18      4       5       1

# %%
#determines how many times the zeroes and ones are repeated.
data['Result'].value_counts()
# Out:
# 1    71
# 0    28
# Name: Result, dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %%
#countplot 
sns.countplot(data['Result'],palette=["#0e0", "#f00"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#line plot
sns.lineplot(data['Age'],data['Smokes'])

sns.set_style("whitegrid") 

sns.set_context("poster")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#barplot
data.dropna(axis=0,inplace=True)   
plt.xlabel('Alcohol bottles consumed')
plt.ylabel('Age of Consumers')
plt.bar(data['Alkhol'],data['Age'] ,color ='green',width = 0.4)
# Out:
# <BarContainer object of 99 artists>

# %%
#barplot

#removing missing values from the dataframe
data.dropna(axis=0,inplace=True)
plt.xlabel(' Smokers')
plt.ylabel('Age of Smokers')
plt.bar(data['Smokes'],data['Age'] ,color ='blue',width = 0.4)
# Out:
# <BarContainer object of 99 artists>

# %%
#Importing the model and assigning the data for training and test set
from sklearn.model_selection import train_test_split
Y = data1['Result']
X = data1.drop(columns=['Result'])
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=9)

# %%
print('X train shape: ', X_train.shape)
print('Y train shape: ', Y_train.shape)
print('X test shape: ', X_test.shape)
print('Y test shape: ', Y_test.shape)
# Out:
# X train shape:  (79, 4)
# Y train shape:  (79,)
# X test shape:  (20, 4)
# Y test shape:  (20,)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression

# We defining the model
logreg = LogisticRegression(C=10)

# We train the model
logreg.fit(X_train, Y_train)

# We predict target values
Y_predict1 = logreg.predict(X_test)

# %%
# The confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

logreg_cm = confusion_matrix(Y_test, Y_predict1)
print(logreg_cm)
f, ax = plt.subplots(figsize=(5,5))
sns.heatmap(logreg_cm, annot=True, linewidth=0.7, linecolor='cyan', fmt='g', ax=ax, cmap="YlGnBu")
plt.title('Logistic Regression Classification Confusion Matrix\n')
plt.xlabel('Y predict')
plt.ylabel('Y test')
plt.show()
# Out:
# [[ 5  2]
#  [ 1 12]]

# %%
# Test score
score_logreg = logreg.score(X_test, Y_test)
print('Test Accuracy')
print(score_logreg)
# Out:
# Test Accuracy
# 0.85
